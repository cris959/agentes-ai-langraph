# %% [markdown]
# <a href="https://colab.research.google.com/github/cris959/agentes-ai-langraph/blob/main/laboratorio_google_genai_2_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata
from google import genai

try:
    # Levantamos tu clave de los secretos de Colab
    api_key = userdata.get("GEMINI_KEY")

    # Inicializamos el cliente oficial de Google
    client = genai.Client(api_key=api_key)
    print("✅ Cliente de Google GenAI inicializado correctamente.")
except Exception as e:
    print(f"❌ Error al inicializar: {e}")
# Out:
# ✅ Cliente de Google GenAI inicializado correctamente.

# %%
def consultar_gemini(tema: str) -> str:
    """
    Función didáctica para enviar un prompt estructurado a Gemini 2.5 Flash
    """
    # Armamos el prompt dinámico con el tema que ingrese el usuario
    prompt = f"Explica de manera clara y actualizada cuáles son los impactos de la inteligencia artificial en el área de {tema}."

    try:
        # Invocamos al modelo que descubrimos que tenés activo y con cuota libre
        response = client.models.generate_content(
            model='gemini-2.5-flash',
            contents=prompt,
        )
        return response.text
    except Exception as e:
        return f"❌ Error en la petición: {e}"

# %%
# Definimos el tema que queremos evaluar hoy
tema_interes = "educación"

print(f"🧠 Consultando a Gemini 2.5 sobre el impacto en: {tema_interes}...\n")

# Llamamos a nuestra función de la Celda 2
resultado = consultar_gemini(tema_interes)

# Mostramos el resultado final
print("-" * 60)
print(resultado)
print("-" * 60)
# Out:
# 🧠 Consultando a Gemini 2.5 sobre el impacto en: educación...
#
# ------------------------------------------------------------
# La Inteligencia Artificial (IA) está transformando el panorama educativo a un ritmo vertiginoso, ofreciendo oportunidades sin precedentes y planteando desafíos significativos. Su impacto es multidimensional, afectando desde la administración escolar hasta la experiencia de aprendizaje del estudiante y la práctica docente.
#
# Aquí te presento un análisis claro y actualizado de sus principales impactos:
#
# ---
#
# ## Impactos Positivos y Oportunidades de la IA en Educación
#
# 1.  **Personalización del Aprendizaje (Rutas Adaptativas):**
#     *   **Descripción:** La IA puede analizar el estilo de aprendizaje, el ritmo, las fortalezas y debilidades de cada estudiante para crear rutas de aprendizaje individualizadas. Plataformas adaptativas sugieren contenidos, ejercicios y recursos específicos que se ajustan al progreso del alumno en tiempo real.
#     *   **Impacto:** Mejora la retención del conocimiento, aumenta la motivación y permite que cada estudiante avance a su propio ritmo, reduciendo la frustración y la deserción escolar.
#
# 2.  **Automatización de Tareas Administrativas y de Evaluación:**
#     *   **Descripción:** La IA puede encargarse de tareas repetitivas como la calificación de exámenes de opción múltiple, la corrección de ensayos (con ciertos límites), la gestión de horarios, el seguimiento de la asistencia y la generación de informes.
#     *   **Impacto:** Libera tiempo valioso para los docentes, permitiéndoles concentrarse en actividades de mayor valor pedagógico, como la interacción personalizada con los estudiantes, el diseño de clases innovadoras y el desarrollo profesional.
#
# 3.  **Acceso a la Educación y Recursos:**
#     *   **Descripción:** Herramientas de IA pueden traducir contenidos educativos a múltiples idiomas, transcribir audio a texto (y viceversa) para personas con discapacidad auditiva o visual, y generar explicaciones simplificadas de conceptos complejos.
#     *   **Impacto:** Democratiza el acceso al conocimiento, derribando barreras idiomáticas y de discapacidad, y haciendo la educación más inclusiva para poblaciones diversas.
#
# 4.  **Análisis de Datos y Predicción del Rendimiento:**
#     *   **Descripción:** La IA puede procesar grandes volúmenes de datos sobre el rendimiento estudiantil, el comportamiento en la plataforma, la participación y otros factores. Puede identificar patrones, predecir qué estudiantes están en riesgo de abandono escolar o de bajo rendimiento, y señalar áreas del currículo que necesitan ser reforzadas.
#     *   **Impacto:** Permite la intervención temprana por parte de los docentes y administradores, optimiza las estrategias pedagógicas y mejora continuamente la calidad de la enseñanza.
#
# 5.  **Creación de Contenidos Educativos Innovadores:**
#     *   **Descripción:** Las IA generativas (como los modelos de lenguaje) pueden crear material didáctico, resúmenes, preguntas de examen, ejemplos, casos de estudio y escenarios simulados. También pueden potenciar entornos de aprendizaje inmersivos como la realidad virtual y aumentada.
#     *   **Impacto:** Proporciona a los educadores herramientas para generar contenido fresco, relevante y dinámico, adaptado a diferentes contextos y niveles, enriqueciendo la experiencia de aprendizaje.
#
# 6.  **Asistentes y Tutores Virtuales:**
#     *   **Descripción:** Chatbots y asistentes virtuales basados en IA pueden ofrecer apoyo instantáneo a los estudiantes, respondiendo preguntas frecuentes, proporcionando explicaciones adicionales, guiando en la resolución de problemas o incluso ayudando con la investigación.
#     *   **Impacto:** Ofrece apoyo continuo fuera del horario escolar, refuerza el aprendizaje y proporciona una retroalimentación inmediata, complementando el rol del docente.
#
# ---
#
# ## Desafíos y Preocupaciones de la IA en Educación
#
# 1.  **Brecha Digital y Equidad:**
#     *   **Desafío:** La implementación de IA requiere infraestructura tecnológica, conectividad a internet y dispositivos. Esto puede acentuar la brecha digital entre estudiantes de diferentes contextos socioeconómicos, profundizando las desigualdades existentes.
#     *   **Impacto:** Riesgo de exclusión para aquellos que no tienen acceso a la tecnología o la alfabetización digital necesaria, creando una "educación de dos velocidades".
#
# 2.  **Sesgos y Discriminación en Algoritmos:**
#     *   **Desafío:** Los algoritmos de IA se entrenan con datos existentes. Si esos datos reflejan sesgos sociales o culturales, la IA puede perpetuar o incluso amplificar la discriminación, por ejemplo, en la evaluación o en la recomendación de rutas de aprendizaje, afectando desproporcionadamente a ciertos grupos de estudiantes.
#     *   **Impacto:** Puede llevar a evaluaciones injustas, limitar oportunidades o reforzar estereotipos, minando la equidad y la inclusión.
#
# 3.  **Privacidad y Seguridad de Datos:**
#     *   **Desafío:** Las plataformas de IA en educación recopilan grandes cantidades de datos sensibles sobre los estudiantes (rendimiento académico, comportamiento, datos personales). La gestión de esta información plantea serios riesgos de privacidad y seguridad si no se protege adecuadamente.
#     *   **Impacto:** Potencial de uso indebido de datos, filtraciones, o perfilado de estudiantes sin su consentimiento, lo que requiere estrictas regulaciones y políticas de protección de datos.
#
# 4.  **Impacto en Habilidades Humanas Fundamentales:**
#     *   **Desafío:** Una excesiva dependencia de la IA podría mermar el desarrollo de habilidades críticas como el pensamiento crítico, la resolución creativa de problemas, la interacción social, la autonomía intelectual y la capacidad de análisis profundo.
#     *   **Impacto:** Los estudiantes podrían perder la capacidad de discernir información, generar ideas originales o colaborar eficazmente, habilidades esenciales para el siglo XXI. La IA también facilita el plagio.
#
# 5.  **Formación y Adaptación Docente:**
#     *   **Desafío:** Muchos docentes carecen de la formación necesaria para comprender, implementar y aprovechar eficazmente las herramientas de IA en sus clases. Existe resistencia al cambio o preocupación por la sustitución de su rol.
#     *   **Impacto:** Limita la adopción efectiva de la IA, genera ansiedad en el profesorado y requiere programas de desarrollo profesional robustos para transformar las prácticas pedagógicas.
#
# 6.  **Costos y Recursos:**
#     *   **Desafío:** La implementación de soluciones de IA a gran escala puede ser costosa, requiriendo inversión en software, hardware, infraestructura de red y personal técnico especializado para su mantenimiento y gestión.
#     *   **Impacto:** Las instituciones con menos recursos pueden quedarse atrás, aumentando las disparidades educativas entre ellas.
#
# 7.  **Fiabilidad y Transparencia de los Algoritmos:**
#     *   **Desafío:** Muchos algoritmos de IA funcionan como "cajas negras", lo que dificulta entender cómo llegan a ciertas conclusiones o recomendaciones. Esto genera falta de transparencia y puede ser problemático en decisiones críticas (por ejemplo, evaluaciones).
#     *   **Impacto:** Riesgo de que se tomen decisiones educativas importantes basándose en algoritmos no auditables o que puedan cometer errores difíciles de detectar y corregir.
#
# ---
#
# **Conclusión:**
#
# La Inteligencia Artificial no es una moda pasajera en educación; es una fuerza transformadora con el potencial de redefinir radicalmente cómo aprendemos y enseñamos. Sin embargo, su éxito yace en una implementación **ética, responsable y bien planificada**. No se trata de reemplazar al educador, sino de potenciarlo, liberarlo de tareas monótonas y permitirle enfocarse en el acompañamiento humano, la empatía y el desarrollo de habilidades complejas.
#
# Para aprovechar al máximo la IA, es fundamental invertir en formación docente, garantizar la equidad en el acceso, establecer marcos de privacidad y seguridad robustos, y mantener un enfoque crítico para asegurar que la tecnología sirva a los objetivos pedagógicos y no al revés. El futuro de la educación con IA será una colaboración entre la inteligencia humana y la artificial.
# ------------------------------------------------------------
